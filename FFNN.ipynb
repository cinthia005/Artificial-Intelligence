# %% [markdown]
# <a href="https://colab.research.google.com/github/cinthia005/Artificial-Intelligence/blob/main/FFNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **AF5_Artificial Neural Network: feedforward**
# **Team:**
#
# *   Cinthia Janeth Pecina Hernández - 2062979
#
# **Career:** Biomedical Engineering
#
# **Group:** 002
#
# **Class:** Artificial Inteligence
#
# **Professor:** Daniel Isaías López Páez
#
# **Hour:** MWF N2
#
# **Objective:** The objective is to design, train, and evaluate a Feedforward Neural Network to classify handwritten digits from the MNIST dataset using Keras/TensorFlow in Google Colab.

# %% [markdown]
# **1. Load Libraries**

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# **2. Load data**

# %%
# Load MNIST dataset using Keras load_data() function
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Display the dataset information
print("\nDataset Information:")
print("Training images shape:", train_images.shape)
print("Training labels shape:", train_labels.shape)
print("Test images shape:", test_images.shape)
print("Test labels shape:", test_labels.shape)
print("Number of classes: 10 (digits 0-9)")
# Out:
# Dataset Information:
# Training images shape: (60000, 28, 28)
# Training labels shape: (60000,)
# Test images shape: (10000, 28, 28)
# Test labels shape: (10000,)
# Number of classes: 10 (digits 0-9)

# %% [markdown]
# **3. Data Preprocessing**

# %%
# Normalize pixel values to range [0, 1]
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

print("\nData normalized: Pixel values scaled to [0, 1]")

# Convert labels to categorical one-hot encoding
train_labels_cat = to_categorical(train_labels, 10)
test_labels_cat = to_categorical(test_labels, 10)

print("Labels converted to categorical format")

# Display sample images from the dataset
print("\nDisplaying sample images from MNIST dataset:")
plt.figure(figsize=(12, 4))
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(train_images[i], cmap='gray')
    plt.title(f'Label: {train_labels[i]}')
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Data normalized: Pixel values scaled to [0, 1]
# Labels converted to categorical format
#
# Displaying sample images from MNIST dataset:

# %% [markdown]
# **4. Model Selection and Training**

# %%
# Build Feedforward Neural Network Model
print("\nBuilding Feedforward Neural Network Model...")

model = Sequential([
    Flatten(input_shape=(28, 28)),      # Input layer: flatten 28x28 images to 784 pixels
    Dense(128, activation='relu'),      # First hidden layer: 128 neurons with ReLU
    Dense(64, activation='relu'),       # Second hidden layer: 64 neurons with ReLU
    Dense(10, activation='softmax')     # Output layer: 10 neurons with Softmax
])

print("Model architecture created successfully!")

# Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("Model compiled with:")
print("- Optimizer: Adam")
print("- Loss function: Categorical Crossentropy")
print("- Metric: Accuracy")

# Display model architecture
print("\nModel Summary:")
model.summary()

# Train the model using fit function
print("\nStarting model training...")
history = model.fit(
    train_images,
    train_labels_cat,
    epochs=10,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)

print("Model training completed!")

# Plot training history
print("\nPlotting training history...")
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy During Training')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss During Training')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Building Feedforward Neural Network Model...
# Model architecture created successfully!
# Model compiled with:
# - Optimizer: Adam
# - Loss function: Categorical Crossentropy
# - Metric: Accuracy
#
# Model Summary:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_4 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,386 (427.29 KB)
#  Trainable params: 109,386 (427.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Starting model training...
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8585 - loss: 0.4819 - val_accuracy: 0.9548 - val_loss: 0.1530
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9645 - loss: 0.1190 - val_accuracy: 0.9688 - val_loss: 0.1075
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9778 - loss: 0.0756 - val_accuracy: 0.9724 - val_loss: 0.0907
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9822 - loss: 0.0583 - val_accuracy: 0.9736 - val_loss: 0.0881
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9872 - loss: 0.0396 - val_accuracy: 0.9707 - val_loss: 0.1053
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9899 - loss: 0.0327 - val_accuracy: 0.9728 - val_loss: 0.1014
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9922 - loss: 0.0270 - val_accuracy: 0.9767 - val_loss: 0.0871
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9927 - loss: 0.0220 - val_accuracy: 0.9752 - val_loss: 0.0994
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9950 - loss: 0.0165 - val_accuracy: 0.9737 - val_loss: 0.1102
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9948 - loss: 0.0169 - val_accuracy: 0.9753 - val_loss: 0.1120
# Model training completed!
#
# Plotting training history...

# %% [markdown]
# **5. Model Testing**

# %%
# Evaluate the model on test data using evaluate function
print("\nEvaluating model on test data...")
test_loss, test_accuracy = model.evaluate(test_images, test_labels_cat, verbose=0)

print("=== MODEL EVALUATION RESULTS ===")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

# Make 5 different predictions with test data
print("\n=== 5 PREDICTIONS ===")

for i in range(5):
    # Get prediction for a test sample
    prediction = model.predict(test_images[i:i+1], verbose=0)
    predicted_label = np.argmax(prediction)
    actual_label = test_labels[i]

    # Display prediction results
    print(f"\nPrediction {i+1}:")
    print(f"Model prediction: {predicted_label}")
    print(f"Actual value: {actual_label}")
    print(f"Confidence: {np.max(prediction):.4f}")

    # Show the corresponding image
    plt.figure(figsize=(3, 3))
    plt.imshow(test_images[i], cmap='gray')
    plt.title(f'Pred: {predicted_label}, Actual: {actual_label}')
    plt.axis('off')
    plt.show()

print("\n=== EVALUATION ===")

# Generate predictions for all test data
all_predictions = model.predict(test_images, verbose=0)
all_predicted_labels = np.argmax(all_predictions, axis=1)

# Classification report
print("\nClassification Report:")
print(classification_report(test_labels, all_predicted_labels))

# Save the trained model
model.save('mnist_ffnn_model.h5')
print("\nModel saved as 'mnist_ffnn_model.h5'")

# Final summary
print("\n" + "="*50)
print("FINAL TRAINING SUMMARY")
print("="*50)
print("Network Architecture: 784-128-64-10")
print("Activation Functions:")
print("  - Hidden layers: ReLU")
print("  - Output layer: Softmax")
print("Loss Function: Categorical Crossentropy")
print("Optimizer: Adam")
print(f"Final Test Accuracy: {test_accuracy:.4f}")
print(f"Final Test Loss: {test_loss:.4f}")
print("Training completed successfully!")
print("="*50)
# Out:
# Evaluating model on test data...
# === MODEL EVALUATION RESULTS ===
# Test Loss: 0.0879
# Test Accuracy: 0.9777
#
# === 5 PREDICTIONS ===
#
# Prediction 1:
# Model prediction: 7
# Actual value: 7
# Confidence: 1.0000
# Prediction 2:
# Model prediction: 2
# Actual value: 2
# Confidence: 1.0000
# Prediction 3:
# Model prediction: 1
# Actual value: 1
# Confidence: 0.9998
# Prediction 4:
# Model prediction: 0
# Actual value: 0
# Confidence: 1.0000
# Prediction 5:
# Model prediction: 4
# Actual value: 4
# Confidence: 1.0000
# === EVALUATION ===
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       980
#            1       1.00      0.99      0.99      1135
#            2       0.98      0.98      0.98      1032
#            3       0.97      0.98      0.97      1010
#            4       0.96      0.98      0.97       982
#            5       0.98      0.97      0.98       892
#            6       0.98      0.98      0.98       958
#            7       0.98      0.98      0.98      1028
#            8       0.98      0.97      0.97       974
#            9       0.96      0.97      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000
#
#
# Model saved as 'mnist_ffnn_model.h5'
#
# ==================================================
# FINAL TRAINING SUMMARY
# ==================================================
# Network Architecture: 784-128-64-10
# Activation Functions:
#   - Hidden layers: ReLU
#   - Output layer: Softmax
# Loss Function: Categorical Crossentropy
# Optimizer: Adam
# Final Test Accuracy: 0.9777
# Final Test Loss: 0.0879
# Training completed successfully!
# ==================================================
